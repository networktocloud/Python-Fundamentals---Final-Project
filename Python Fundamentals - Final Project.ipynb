# %%
# Objective of this notebook:
# Create an interactive GUI using a widget. This GUI should import one of the dataframes available
# from seaborn, and the GUI should process the data in some way (sum a column of values) and then display the desired output.

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display
import seaborn as sns

# %%
df_mpg = sns.load_dataset("mpg")
df_mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
#Hit button to sum the amount of cylinders and display
cylinders = df_mpg.cylinders
def add_me(obj):
    total = 0
    with output:
        for cyl in cylinders:
            total += cyl
        print("Total cylinders of {} button is: ".format(obj.description) + str(total))

output = widgets.Output()

show_total_cylinders = widgets.Button(description = "Add me", icon = "plus")

display(show_total_cylinders, output)
show_total_cylinders.on_click(add_me)
# Out:
# Button(description='Add me', icon='plus', style=ButtonStyle())
# Output()

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# ipywidgets          8.1.2
# pandas              2.2.1
# seaborn             0.13.2
# session_info        1.0.0
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                         10.2.0
# anyio                       NA
# asttokens                   NA
# attr                        23.1.0
# attrs                       23.1.0
# babel                       2.11.0
# brotli                      1.0.9
# certifi                     2024.02.02
# cffi                        1.16.0
# charset_normalizer          2.0.4
# colorama                    0.4.6
# comm                        0.2.1
# cycler                      0.12.1
# cython_runtime              NA
# dateutil                    2.8.2
# debugpy                     1.6.7
# decorator                   5.1.1
# defusedxml                  0.7.1
# executing                   0.8.3
# ...
